# %%
import os
from dotenv import load_dotenv
load_dotenv()

from hud import HUDClient
from hud.adapters.claude.adapter import ClaudeAdapter
from agent.claude import ClaudeAgent

from anthropic import Anthropic
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       5 from hud import HUDClient
#       6 from hud.adapters.claude.adapter import ClaudeAdapter
# ----> 7 from agent.claude import ClaudeAgent
#       9 from anthropic import Anthropic
#
# ModuleNotFoundError: No module named 'agent'

# %%
# initialize HUD client
client = HUDClient(api_key=os.getenv("HUD_API_KEY"))

# initalize Claude Computer Use agent
anthropic = Anthropic(api_key=os.getenv("ANTHROPIC_API_KEY"))

# initialize adapter to interact with the environment
cua_adapter = ClaudeAdapter()

# %%
# load OSWorld environment
gym = await client.load_gym(id="OSWorld-Ubuntu")

# load OSWorld evalset
evalset = await client.load_evalset(id="OSWorld-Ubuntu")

# create a run that will host all evaluations
run = await client.create_run(name="Claude-test-OSWorld", gym=gym, evalset=evalset)

# fetch all task ids from the run
tasks = await run.fetch_task_ids()
print(f"Total tasks in OSWorld: {len(tasks)}")
# Out:
# Total tasks in OSWorld: 368

# %%
# It may take around ~1 minute to initialize the OSWorld environment and reset to a task

# make a HUD environment
env = await run.make()
await env.wait_for_ready()

# reset to a task with an observation (screenshot and text)
obs = await env.reset(task_id=tasks[1])
print(f"Task description: {obs.text}")

# %%
# agent loop
agent = ClaudeAgent(anthropic)

for i in range(8):
    # rescale screenshot to Claude's resolution
    screenshot = cua_adapter.rescale(obs.screenshot)

    # agent's next action
    done, response = await agent.predict(screenshot, obs.text)
    if done:
        env.final_response = str(response)
        break

    # convert to HUD action space
    actions = cua_adapter.adapt_list([response])
    print(f"Agent's action: {response}")

    # step the environment forward
    obs, reward, terminated, info = await env.step(actions)

    # drop out if terminated
    if terminated:
        break
    print(f"Step {i+1} completed")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 9
#       6 screenshot = cua_adapter.rescale(obs.screenshot)
#       8 # agent's next action
# ----> 9 done, response = await agent.predict(screenshot, obs.text)
#      10 if done:
#      11     env.final_response = str(response)
#
# File ~/Projects/hud/CAR-bench/hud-sdk/agent/claude.py:28, in ClaudeAgent.predict(self, screenshot, text)
#      25 if message:
#      26     self.conversation.append(message)
# ---> 28 response = self._generate_response()
#      30 # Check if this response contains any tool_use blocks
#      31 for block in response.content:
#
# File ~/Projects/hud/CAR-bench/hud-sdk/agent/claude.py:122, in ClaudeAgent._generate_response(self)
#     119 thinking = {"type": "enabled", "budget_tokens": self.thinking_budget}
#     121 try:
# --> 122     response = self.client.beta.messages.create(
#     123         model=self.model,
#     124         max_tokens=self.max_tokens,
#     125         messages=self.conversation,  # Use the full conversation including assistant responses
#     126         tools=tools,
#     127         betas=[beta_flag],
#     128         thinking=thinking,
#     129     )
#     130     return response
#     131 except Exception as e:
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/anthropic/_utils/_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/anthropic/resources/beta/messages/messages.py:958, in Messages.create(self, max_tokens, messages, model, metadata, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, betas, extra_headers, extra_query, extra_body, timeout)
#     948     warnings.warn(
#     949         f"The model '{model}' is deprecated and will reach end-of-life on {DEPRECATED_MODELS[model]}.\nPlease migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.",
#     950         DeprecationWarning,
#     951         stacklevel=3,
#     952     )
#     954 extra_headers = {
#     955     **strip_not_given({"anthropic-beta": ",".join(str(e) for e in betas) if is_given(betas) else NOT_GIVEN}),
#     956     **(extra_headers or {}),
#     957 }
# --> 958 return self._post(
#     959     "/v1/messages?beta=true",
#     960     body=maybe_transform(
#     961         {
#     962             "max_tokens": max_tokens,
#     963             "messages": messages,
#     964             "model": model,
#     965             "metadata": metadata,
#     966             "stop_sequences": stop_sequences,
#     967             "stream": stream,
#     968             "system": system,
#     969             "temperature": temperature,
#     970             "thinking": thinking,
#     971             "tool_choice": tool_choice,
#     972             "tools": tools,
#     973             "top_k": top_k,
#     974             "top_p": top_p,
#     975         },
#     976         message_create_params.MessageCreateParams,
#     977     ),
#     978     options=make_request_options(
#     979         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     980     ),
#     981     cast_to=BetaMessage,
#     982     stream=stream or False,
#     983     stream_cls=Stream[BetaRawMessageStreamEvent],
#     984 )
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/anthropic/_base_client.py:1336, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1322 def post(
#    1323     self,
#    1324     path: str,
#    (...)
#    1331     stream_cls: type[_StreamT] | None = None,
#    1332 ) -> ResponseT | _StreamT:
#    1333     opts = FinalRequestOptions.construct(
#    1334         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1335     )
# -> 1336     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/anthropic/_base_client.py:1013, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1010 else:
#    1011     retries_taken = 0
# -> 1013 return self._request(
#    1014     cast_to=cast_to,
#    1015     options=options,
#    1016     stream=stream,
#    1017     stream_cls=stream_cls,
#    1018     retries_taken=retries_taken,
#    1019 )
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/anthropic/_base_client.py:1039, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1036 options = self._prepare_options(options)
#    1038 remaining_retries = options.get_max_retries(self.max_retries) - retries_taken
# -> 1039 request = self._build_request(options, retries_taken=retries_taken)
#    1040 self._prepare_request(request)
#    1042 kwargs: HttpxSendArgs = {}
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/anthropic/_base_client.py:487, in BaseClient._build_request(self, options, retries_taken)
#     484     else:
#     485         raise RuntimeError(f"Unexpected JSON data type, {type(json_data)}, cannot merge with `extra_body`")
# --> 487 headers = self._build_headers(options, retries_taken=retries_taken)
#     488 params = _merge_mappings(self.default_query, options.params)
#     489 content_type = headers.get("Content-Type")
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/anthropic/_base_client.py:428, in BaseClient._build_headers(self, options, retries_taken)
#     418 custom_headers = options.headers or {}
#     419 headers_dict = _merge_mappings(
#     420     {
#     421         "x-stainless-timeout": str(options.timeout.read)
#    (...)
#     426     custom_headers,
#     427 )
# --> 428 self._validate_headers(headers_dict, custom_headers)
#     430 # headers are case-insensitive while dictionaries are not.
#     431 headers = httpx.Headers(headers_dict)
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/anthropic/_client.py:180, in Anthropic._validate_headers(self, headers, custom_headers)
#     177 if isinstance(custom_headers.get("Authorization"), Omit):
#     178     return
# --> 180 raise TypeError(
#     181     '"Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"'
#     182 )
#
# TypeError: "Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"

# %%
# evaluate environment state
result = await env.evaluate()
print(f"Evaluation result: {result}")

# close environment
await env.close()
# Out:
# Evaluation result: 1.0

# %%
analytics = await run.get_analytics()
print(analytics)
# Out:
# Run: Claude-test-OSWorld (ID: de4927e8-f196-49cd-8330-39af16ad9112)
# Created: 2025-03-22 21:53:01
# ------------------------------------------------------------
# Progress: 1/1 tasks completed (
#             100.0% completion rate)
#
# Status Distribution:
# completed : ██████████████████████████████████████████████████ 1 (100.0%)
#
# Average Score: 1.00
# Score:  1.00/1.00
